# %%
import os 
from dotenv import load_dotenv
load_dotenv()

os.environ['COHERE_API_KEY']= os.getenv('COHERE_API_KEY')

## Langsmith Tracking
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_cohere import ChatCohere
llm = ChatCohere()
llm
# Out:
# ChatCohere(client=<cohere.client.Client object at 0x000002079A7DBF40>, async_client=<cohere.client.AsyncClient object at 0x000002079A7D92A0>, cohere_api_key=SecretStr('**********'))

# %%
import os 
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')

from langchain_openai import ChatOpenAI
llm_openai = ChatOpenAI(model="gpt-4o-mini", temperature=0.1, max_tokens=1000)

# %%
response = llm_openai.invoke("What is the capital of France?")
print(response)
# Out:
# content='The capital of France is Paris.' response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 14, 'total_tokens': 21, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_34a54ae93c', 'finish_reason': 'stop', 'logprobs': None} id='run-204dca4c-0856-4a48-a756-57b5db478dd3-0' usage_metadata={'input_tokens': 14, 'output_tokens': 7, 'total_tokens': 21}

# %%
response.content
# Out:
# 'The capital of France is Paris.'
